# %%
import kivy
kivy.require("2.3.1")

# %%
from kivy.app import App
from kivy.uix.label import Label

# %%
class App1(App):
    def build(self):
        return Label(text="hello")

# %%
App1().run()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 App1().run()
#
# File d:\PY\venv\v312e1\Lib\site-packages\kivy\app.py:955, in App.run(self)
#     952 def run(self):
#     953     '''Launches the app in standalone mode.
#     954     '''
# --> 955     self._run_prepare()
#     956     runTouchApp()
#     957     self._stop()
#
# File d:\PY\venv\v312e1\Lib\site-packages\kivy\app.py:924, in App._run_prepare(self)
#     922 if not self.built:
#     923     self.load_config()
# --> 924     self.load_kv(filename=self.kv_file)
#     925     root = self.build()
#     926     if root:
#
# File d:\PY\venv\v312e1\Lib\site-packages\kivy\app.py:677, in App.load_kv(self, filename)
#     675 else:
#     676     try:
# --> 677         default_kv_directory = dirname(getfile(self.__class__))
#     678         if default_kv_directory == '':
# ...
